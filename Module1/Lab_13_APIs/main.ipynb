# %% [markdown]
# ## Challenge 1: Get a Picture

# %%
import json
import requests

# %%
response = requests.get('https://xkcd.com')

# %%
print(response.request.url)
print(response.request.body)
print(response.request.headers)
# Out:
# https://xkcd.com/
# None
# {'User-Agent': 'python-requests/2.28.1', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
retry_after = response.headers.get('Expires')
print(retry_after)
# Out:
# Wed, 25 Jan 2023 03:56:40 GMT

# %%
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '3039', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Tue, 24 Jan 2023 05:08:14 GMT', 'ETag': 'W/"63cf67be-1e2f"', 'Expires': 'Wed, 25 Jan 2023 03:56:40 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Wed, 25 Jan 2023 11:31:35 GMT', 'Age': '246', 'X-Served-By': 'cache-dfw-kdfw8210070-DFW, cache-cdg20772-CDG', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '9, 1', 'X-Timer': 'S1674646295.492833,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
image_path = 'https://imgs.xkcd.com/comics/all_adobe_updates.png'

# %%
import IPython
IPython.display.Image(image_path, width = 250)

# %% [markdown]
# ## Challenge 2: Get a password

# %%
response2 = requests.post('https://httpbin.org/get', data={'key1': 'value1'})
print(response2.request.url)
print(response2.request.body)
print(response2.request.headers)
# Out:
# https://httpbin.org/get
# key1=value1
# {'User-Agent': 'python-requests/2.28.1', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Length': '11', 'Content-Type': 'application/x-www-form-urlencoded'}

# %%
url = 'https://httpbin.org/post'
param = {'things':2,'total':25}

req = requests.post(url, params = param)
print(req.content)
# Out:
# b'{\n  "args": {\n    "things": "2", \n    "total": "25"\n  }, \n  "data": "", \n  "files": {}, \n  "form": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Content-Length": "0", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.28.1", \n    "X-Amzn-Trace-Id": "Root=1-63d13218-268e53f9516f68850d8c0297"\n  }, \n  "json": null, \n  "origin": "185.146.221.98", \n  "url": "https://httpbin.org/post?things=2&total=25"\n}\n'

# %%
resp = requests.post(url,params=param)
response.status_code
response.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: Lane Change Highway</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<!-- <script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script> -->\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="Lane Change Highway">\n<meta property="og:url" content="https://xkcd.com/2728/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/lane_change_highway_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<di
# ...

# %%
parameter = {'username': 'one@one.com', 'password': 'oneone'}

# %%
r = requests.post("https://httpbin.org/post",data=parameter)
print (r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "oneone",
#     "username": "one@one.com"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "38",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.28.1",
#     "X-Amzn-Trace-Id": "Root=1-63d12ed0-05d5c4366d63a1bb61af6037"
#   },
#   "json": null,
#   "origin": "185.146.221.98",
#   "url": "https://httpbin.org/post"
# }

# %%
file = open("test.txt", "w")
file.write(r.text)
file.close()

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke

# %%
import requests
import json

# %%
username = 'eljmorgan'
token = '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'

# %%
url = 'https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger'

# %%
login = requests.get(url, auth = (username, token) )
login
# Out:
# <Response [200]>

# %%
search = login.json()
search
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0016.scavengerhunt',
#    'path': '47222/.0016.scavengerhunt',
#    'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
# ...

# %%
repo_files_names = [item["name"] for item in search["items"]]
repo_files_names.sort()
repo_files_names
# Out:
# ['.0001.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0006.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0012.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0024.scavengerhunt']

# %%
repo_files_urls = {item["name"]: item["url"] for item in search["items"]}
repo_files_urls
# Out:
# {'.0016.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0009.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/97881/.0009.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0021.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/30351/.0021.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0023.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/55417/.0023.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0019.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/70751/.0019.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0002.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/88596/.0002.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
# ...

# %%
repo_files = [requests.get(repo_files_urls[repo_filename]) for repo_filename in repo_files_names]
repo_files
# Out:
# [<Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>]
