# %%
import pandas as pd

# %% [markdown]
# ### Part 1: Upload the data
# ### Part 2: Analyze your data and create a plan for data preparation

# %%
df = pd.read_csv('example_data_cleaning.csv', index_col=False)
df.head()
df.shape
# Out:
# (30, 7)

# %% [markdown]
# Missing values
#
# Change 28 29 to 15 16
#
#
# Sort by transaction, no index needed
#
# profession all lower, BirthYear must be int
#
# Drop departement column
#
# Outliers
#
# Encode categorical data

# %% [markdown]
# ## Part 3: Data cleansing (missing values, outliers, duplicates, data consistently)

# %%
df['TransactionID'].is_unique
df = df.set_index['TransactionID']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4116\2597165163.py in <module>
#       1 df['TransactionID'].is_unique
# ----> 2 df = df.set_index['TransactionID']
#
# TypeError: 'method' object is not subscriptable

# %%
df.isnull().sum()
# Out:
# TransactionID    0
# ClientID         0
# BirthYear        2
# Amount           0
# Profession       2
# Department       0
# Risk             0
# dtype: int64

# %%
null_cols = df.isnull().sum()
null_cols[null_cols > 0]
# Out:
# BirthYear     2
# Profession    2
# dtype: int64

# %%
list(null_cols[null_cols > 0].index)
# Out:
# ['BirthYear', 'Profession']

# %%
null_year = df[(df['BirthYear'].isnull()==True)]
#null_displ = null_displ[['BirthYear', 'Profession']]
null_year
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 28             22     34987        NaN   18990     sailer          78    High
# 29              7     34988        NaN   12330    Manager          78  Medium

# %%
null_prof = df[(df['Profession'].isnull()==True)]
null_prof
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 15             28     35008     1967.0   46370        NaN          78    High
# 16             29     35008     1976.0   50810        NaN          78  Medium

# %%
df[['Profession', 'BirthYear']] = df[['Profession', 'BirthYear']].fillna(0)
df
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 0               4     34985     1923.0     5670      manager          78
# 1              16     34997     1923.0  2399090    developer          78
# 2              25     35006     1923.0    33050           HR          78
# 3              12     34993     1939.0    23430    professor          78
# 4              21     35002     1939.0    16770      manager          78
# 5              11     34992     1944.0    21210   researcher          78
# 6              20     35001     1944.0    14550      student          78
# 7               3     34984     1945.0     3450      student          78
# 8              19     35000     1949.0    12330       barmen          78
# 9               9     34990     1953.0    16770      Manager          78
# 10              8     34989     1958.0    14550           HR          78
# 11              6     34987     1967.0    10110      Manager          78
# ...

# %%
df['BirthYear'] = df['BirthYear'].astype(int)
df['Profession']  = df['Profession'].str.capitalize()
df #formating year and profession
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 0               4     34985       1923     5670      Manager          78
# 1              16     34997       1923  2399090    Developer          78
# 2              25     35006       1923    33050           Hr          78
# 3              12     34993       1939    23430    Professor          78
# 4              21     35002       1939    16770      Manager          78
# 5              11     34992       1944    21210   Researcher          78
# 6              20     35001       1944    14550      Student          78
# 7               3     34984       1945     3450      Student          78
# 8              19     35000       1949    12330       Barmen          78
# 9               9     34990       1953    16770      Manager          78
# 10              8     34989       1958    14550           Hr          78
# 11              6     34987       1967    10110      Manager          78
# ...

# %%
#need to merge 2 rows with 2 rows

out = (df.pivot('id', 'type', 'value')
       .add_prefix('value_').fillna(0)
       .assign(type=df.groupby('id')['type'].first())
       .reset_index()
       [['id','type','value_0','value_1']]
       .rename_axis(columns=[None]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
test = df[(df['BirthYear'] > 2005) | (df['BirthYear'] < 1959)]
test #find a peoples who cannot work due on birth day
# Out:
#     TransactionID  ClientID  BirthYear   Amount  Profession  Department  \
# 0               4     34985     1923.0     5670     manager          78
# 1              16     34997     1923.0  2399090   developer          78
# 2              25     35006     1923.0    33050          HR          78
# 3              12     34993     1939.0    23430   professor          78
# 4              21     35002     1939.0    16770     manager          78
# 5              11     34992     1944.0    21210  researcher          78
# 6              20     35001     1944.0    14550     student          78
# 7               3     34984     1945.0     3450     student          78
# 8              19     35000     1949.0    12330      barmen          78
# 9               9     34990     1953.0    16770     Manager          78
# 10              8     34989     1958.0    14550          HR          78
# 25              1     34982     2013.0    12900     Student          78
# ...

# %%
df.describe()
# Out:
#        TransactionID      ClientID    BirthYear        Amount  Department
# count      30.000000     30.000000    28.000000  3.000000e+01        30.0
# mean       15.500000  34993.833333  1968.321429  1.010097e+05        78.0
# std         8.803408      8.132876    27.960360  4.342616e+05         0.0
# min         1.000000  34982.000000  1923.000000  1.230000e+03        78.0
# 25%         8.250000  34987.250000  1944.750000  1.233000e+04        78.0
# 50%        15.500000  34991.500000  1967.000000  1.899000e+04        78.0
# 75%        22.750000  34999.750000  1988.000000  2.953500e+04        78.0
# max        30.000000  35008.000000  2017.000000  2.399090e+06        78.0

# %%
df2 = df[df.duplicated('ClientID')] #duplicated clients ID
df2
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 12             15     34987     1967.0   30090    Manager          78     Low
# 13             24     34989     1967.0   27870         HR          78  Medium
# 15             28     35008     1967.0   46370        NaN          78    High
# 16             29     35008     1976.0   50810        NaN          78  Medium
# 20             30     34991     1988.0   55250        BDM          78    High
# 28             22     34987        NaN   18990     sailer          78    High
# 29              7     34988        NaN   12330    Manager          78  Medium
