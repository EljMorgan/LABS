# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Supplier', 'ItemCode', 'Description', 'ItemType',
#        'RetailSales', 'RetailTransfers', 'WarehouseSales'],
#       dtype='object')

# %%
df1 = data.groupby(['ItemType'])['RetailSales', 'RetailTransfers','WarehouseSales'].sum().reset_index()
df_melted = df1.melt(id_vars='ItemType', value_vars=['RetailSales', 'RetailTransfers', 'WarehouseSales'])

sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x='ItemType', y='value', hue='variable', data=df_melted)
plt.title('Sales by Item Type')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data_supplier = data.groupby(['Supplier']).sum()
data_supplier['MixSales'] = data_supplier['RetailSales']+data_supplier['RetailTransfers']+data_supplier['WarehouseSales']
supplier_Top10 = data_supplier.sort_values(['MixSales'], ascending = False).head(10).reset_index()
lst= ("RetailSales", "RetailTransfers", "WarehouseSales")
suppliers_Top10_melt=supplier_Top10.melt(id_vars='Supplier', value_vars=["RetailSales", "RetailTransfers", "WarehouseSales"],var_name='sales_type')
ax = sns.barplot(x="value", y='Supplier', data=suppliers_Top10_melt, hue ='sales_type')

# %%
total = data[['WarehouseSales', 'RetailSales', 'RetailTransfers']].value_counts().sum()
#test = data.nlargest(10, total)[['Supplier']]
total
# Out:
# 128355

# %%
retail_item = data.nlargest(10, 'RetailSales')[['Supplier', 'RetailSales']]
retail_item = retail_item.reset_index(drop=True)

# %%
ware_item = data.nlargest(10, 'WarehouseSales')[['Supplier', 'WarehouseSales']]
ware_item = ware_item.reset_index(drop=True)

# %%
trans_item = data.nlargest(10, 'RetailTransfers')[['Supplier', 'RetailTransfers']]
trans_item = trans_item.reset_index(drop=True)

# %%
plt.barh(retail_item.index, retail_item, label = 'Retail Sales')
plt.barh(ware_item.index, ware_item, left = retail_item, label = 'WarehouseSales')
plt.barh(trans_item.index, trans_item, left = ware_item, label = 'RetailTransfers')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9748\1311001520.py in <module>
# ----> 1 plt.barh(retail_item.index, retail_item, label = 'Retail Sales')
#       2 plt.barh(ware_item.index, ware_item, left = retail_item, label = 'WarehouseSales')
#       3 plt.barh(trans_item.index, trans_item, left = ware_item, label = 'RetailTransfers')
#       4 plt.legend()
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2413 @_copy_docstring_and_deprecators(Axes.barh)
#    2414 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2415     return gca().barh(
#    2416         y, width, height=height, left=left, align=align, **kwargs)
#    2417
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2549         """
#    2550         kwargs.setdefault('orientation', 'horizontal')
# -> 2551         patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2552                            align=align, **kwargs)
#    2553         return patches
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2320                 self.set_yscale('log', nonpositive='clip')
#    2321         elif orientation == 'horizontal':
# -> 2322             self._process_unit_info(
#    2323                 [("x", width), ("y", y)], kwargs, convert=False)
#    2324             if log:
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, datasets, kwargs, convert)
#    2524             # Update from data if axis is already set but no unit is set yet.
#    2525             if axis is not None and data is not None and not axis.have_units():
# -> 2526                 axis.update_units(data)
#    2527         for axis_name, axis in axis_map.items():
#    2528             # Return if no axis is set.
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1447         neednew = self.converter != converter
#    1448         self.converter = converter
# -> 1449         default = self.converter.default_units(data, self)
#    1450         if default is not None and self.units is None:
#    1451             self.set_units(default)
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     114         # the conversion call stack is default_units -> axis_info -> convert
#     115         if axis.units is None:
# --> 116             axis.set_units(UnitData(data))
#     117         else:
#     118             axis.units.update(data)
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     190         self._counter = itertools.count()
#     191         if data is not None:
# --> 192             self.update(data)
#     193
#     194     @staticmethod
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     223         # check if convertible to number:
#     224         convertible = True
# --> 225         for val in OrderedDict.fromkeys(data):
#     226             # OrderedDict just iterates over unique values in data.
#     227             _api.check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
plt.barh(data.index,data["RetailSales"],label="Retail Sales")
plt.barh(data.index,data["RetailTransfers"], left = data["RetailSales"], label="Retail Transfers", color = "blue")
plt.barh(data.index,data["WarehouseSales"], left = data["RetailTransfers"], label="Warehouse Sales",color = "green")
plt.legend()

# %%
pdList = [retail_item, ware_item,trans_item]
new_df = pd.concat(pdList, ignore_index=True).fillna(0)
new_df
# Out:
#                 Supplier  RetailSales  WarehouseSales  RetailTransfers
# 0   FIFTH GENERATION INC      1616.60            0.00             0.00
# 1          CROWN IMPORTS      1249.00            0.00             0.00
# 2          CROWN IMPORTS      1170.00            0.00             0.00
# 3          CROWN IMPORTS      1138.36            0.00             0.00
# 4   FIFTH GENERATION INC      1101.39            0.00             0.00
# 5   FIFTH GENERATION INC      1080.89            0.00             0.00
# 6   FIFTH GENERATION INC      1065.28            0.00             0.00
# 7          CROWN IMPORTS      1063.00            0.00             0.00
# 8          CROWN IMPORTS      1037.37            0.00             0.00
# 9          CROWN IMPORTS       992.00            0.00             0.00
# 10         CROWN IMPORTS         0.00        16271.75             0.00
# 11         CROWN IMPORTS         0.00        16079.12             0.00
# 12         CROWN IMPORTS         0.00        15955.46             0.00
# 13         CROWN IMPORTS         0.00        15346.71             0.00
# 14         CROWN IMPORTS         0.00        13736.25             0.00
# 15         CROWN IMPORTS         0.00        13723.71             0.00
# 16         CROWN IMPORTS         0.00        12733.83             0.00
# 17         CROWN IMPORTS         0.00        11995.00             0.00
# 18         CROWN IMPORTS         0.00        11932.79             0.00
# 19         CROWN IMPORTS         0.00        11417.92             0.00
# 20  FIFTH GENERATION INC         0.00            0.00          1587.99
# 21         CROWN IMPORTS         0.00            0.00          1180.00
# 22         CROWN IMPORTS         0.00            0.00          1162.96
# 23         CROWN IMPORTS         0.00            0.00          1160.00
# 24  FIFTH GENERATION INC         0.00            0.00          1077.66
# 25         CROWN IMPORTS         0.00            0.00          1077.00
# 26         CROWN IMPORTS         0.00            0.00          1055.00
# 27         CROWN IMPORTS         0.00            0.00          1038.00
# 28  FIFTH GENERATION INC         0.00            0.00          1030.64
# 29  FIFTH GENERATION INC         0.00            0.00          1008.49

# %%
new_df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Supplier', 'ItemCode', 'Description', 'ItemType',
#        'RetailSales', 'RetailTransfers', 'WarehouseSales'],
#       dtype='object')

# %%
data.groupby('Month')['RetailSales'].mean().plot(y='RetailSales', kind = 'line')
data.groupby('Month')['RetailTransfers'].mean().plot(y='RetailTransfers', kind = 'line')
data.groupby('Month')['WarehouseSales'].mean().plot(y='WarehouseSales', kind = 'line')
plt.legend()
plt.show()

# %%
plt.plot('Month', 'RetailSales', data = data, marker ='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot('Month', 'RetailTransfers', data=data, marker='', color='r', linewidth=2)
plt.plot('Month', 'WarehouseSales', data=data, marker='', color='g',linewidth=2, linestyle = 'dashed')

plt.legend()
plt.show()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
sales_piv_melt=sales_piv.melt(id_vars='Month', value_vars=['RetailSales','RetailTransfers','WarehouseSales'],\
                         var_name='sales type')

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*
